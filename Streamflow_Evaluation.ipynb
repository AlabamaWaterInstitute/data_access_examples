# %%
import Streamflow_Eval

# %%
#site information
#set up for Provo River at river road bridge
NWISreach = '10155200'
NWMsegment = 10373794
startDT ='2020-05-01'
endDT ='2020-05-31'
freq = 'D'

#Run parameter setting function
Streamflow = Streamflow_Eval.Reach_Eval(NWISreach, NWMsegment, startDT, endDT, freq)

#Get NWIS data
Streamflow.NWIS_retrieve()

#Get NWM data
Streamflow.NWM_retrieve()

#Compare NWM performance with USGS observations
Streamflow.NWM_Eval()
# Out:
# Retrieving USGS site  10155200  data
# Retrieving NWM reach  10373794  data
# The NWM demonstrates the following model performance
# R2 =  0.04227849768046543
# RMSE =  451.3027947602754 ft3/s
# Maximum error =  974.5687489333031 ft3/s
# Mean Absolute Percentage Error =  36.09551725476301 %
# Kling-Gupta Efficiency =  [0.18746581]
