# %%
rundict = {
    1: "short_range",
    2: "medium_range",
    3: "medium_range_no_da",
    4: "long_range",
    5: "analysis_assim",
    6: "analysis_assim_extend",
    7: "analysis_assim_extend_no_da",
    8: "analysis_assim_long",
    9: "analysis_assim_long_no_da",
    10: "analysis_assim_no_da",
    11: "short_range_no_da"
}
memdict = {
    1: "mem_1",
    2: "mem_2",
    3: "mem_3",
    4: "mem_4",
    5: "mem_5",
    6: "mem_6",
    7: "mem_7"
}
vardict = {
    1: "channel_rt",
    2: "land",
    3: "reservoir",
    4: "terrain_rt",
    5: "forcing"
}
fcst_cycle = "00"
fcst_hour = "001"
geodict = {
    1: "conus",
    2: "hawaii",
    3: "puertorico"
}
runsuffix = ""

# %%
#runsuffix is not being used, but i'm not going to delete it from everything just in case this whole thing needs to be restructured

#for _no_da run types, the only variable input can be channel_rt

#short_range_hawaii, short_range_hawaii_no_da, analysis_assim_hawaii, and analysis_assim_hawaii_no_da cannot be accomodated because they output every 15 minutes

# %%
def makename (date, run, var, fcst_cycle, fcst_hour, geography, run_type, fhprefix = "", runsuffix = "", varsuffix = "", run_typesuffix = ""):
    return f"nwm.{date}/{run_type}{run_typesuffix}/nwm.t{fcst_cycle}z.{run}{runsuffix}.{var}{varsuffix}.{fhprefix}{fcst_hour}.{geography}.nc"

# %%
varinput = 5

def selectvar(vardict, varinput):
    return vardict[varinput]

try:
    var = selectvar(vardict, varinput)
except:
    var = "variable_error"

# %%
geoinput = 3

def selectgeo(geodict, geoinput):
    return geodict[geoinput]

try:
    geography = selectgeo(geodict, geoinput)
except:
    georaphy = "geography_error"

# %%
runinput = 5

def selectrun(rundict, runinput):
    return rundict[runinput]

try:
    run = selectrun(rundict, runinput)
except:
    run = "run_error"

# %%
from dateutil import rrule
from datetime import datetime

start_date = "20220822"
end_date = "20220824"

for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
    date = dt.strftime('%Y%m%d')

# %%
#setting run_type 
if varinput == 5: #if forcing
    if runinput == 5 and geoinput == 2: #if analysis_assim and hawaii
        run_type = "forcing_analysis_assim_hawaii"
    elif runinput == 5 and geoinput == 3: #if analysis_assim and puerto rico
        run_type = "forcing_analysis_assim_puertorico"
    elif runinput == 1 and geoinput == 2: #if short range and hawaii
        run_type = "forcing_short_range_hawaii"
    elif runinput == 1 and geoinput == 3: #if short range and puerto rico
        run_type = "forcing_short_range_puertorico" 
    elif runinput == 5: #if analysis assim
        run_type = "forcing_analysis_assim"
    elif runinput == 6: #if analysis_assim_extend
        run_type = "forcing_analysis_assim_extend"
    elif runinput == 2: #if medium_range
        run_type = "forcing_medium_range"
    elif runinput == 1: #if short range
        run_type = "forcing_short_range"

elif runinput == 5 and geoinput == 3: #if analysis_assim and puertorico
    run_type = "analysis_assim_puertorico"

elif runinput == 10 and geoinput == 3: #if analysis_assim_no_da and puertorico
    run_type = "analysis_assim_puertorico_no_da"

elif runinput == 1 and geoinput == 3: #if short_range and puerto rico
    run_type = "short_range_puertorico"

elif runinput == 11 and geoinput ==3: #if short_range_no_da and puerto rico
    run_type = "short_range_puertorico_no_da"

else:
    run_type = run

# %%
#setting varsuffix and run_typesuffix (for the file path folder name)
memdict = ""

if memdict == 1:
    varsuffix = "_1"
    run_typesuffix = "_mem1"
elif memdict == 2:
    varsuffix = "_2"
    run_typesuffix = "_mem2"
elif memdict == 3:
    varsuffix = "_3"
    run_typesuffix = "_mem3"
elif memdict == 4:
    varsuffix = "_4"
    run_typesuffix = "_mem4"
elif memdict == 5:
    varsuffix = "_5"
    run_typesuffix = "_mem5"
elif memdict == 6:
    varsuffix = "_6"
    run_typesuffix = "_mem6"
elif memdict == 7:
    varsuffix = "_7"
    run_typesuffix = "_mem7"
else:
    varsuffix = ""
    run_typesuffix = ""

# %%
#setting fhprefix
if runinput == 4 or runinput == 5 or runinput == 6 or runinput == 7 or runinput == 8 or runinput == 9 or runinput == 10: #if analysis_assim (any type)
    fhprefix = "tm"
else:
    fhprefix = "f"

# %%
#for given date,  run, var, fcst_cycle, and geography, print file names for the valid time (the range of fcst_hours) and dates

if runinput == 1: #if short_range
    if varinput == 5: #if forcing
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') #create date range

            for fc in range (0, 29, 1):
                fcst_cycles = (f"{fc:02d}") #create forecast cycle range

                for fh in range (1,19,1):
                    fcst_hours = (f"{fh:03d}") #create forecast hours range
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif varinput == 5 and geoinput == 2: #if forcing and hawaii
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 13, 12):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (1,49,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif varinput == 5 and geoinput == 3: #if forcing and puerto rico
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            fcst_cycles = "06"

            for fh in range (1,48,1):
                fcst_hours = (f"{fh:03d}") 
                print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif geoinput == 3: #if puerto rico
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (6, 19, 12):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (1,48,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d')
            for fc in range (0, 24, 1):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (1,19,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

elif runinput == 2: #if medium_range
    if varinput == 5: #if forcing
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 13, 6):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (0,240,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 
            for fc in range (0, 19, 6):
                fcst_cycles = (f"{fc:02d}")

                if memdict == 1: #if medium_range_mem1
                    if varinput == 1 or varinput == 3: #if channel or reservoir
                        for fh in range (1, 241, 1):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

                    elif varinput == 2 or varinput ==4: #if land or terrain
                        for fh in range (3, 241, 3):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
                    else:
                        print ("varinput error")

                elif memdict == 2 or memdict == 3 or memdict == 4 or memdict == 5 or memdict == 6 or memdict == 7:#if medium_range_mem_2 through _mem7
                    if varinput == 1 or varinput ==3: #if channel or reservoir
                        for fh in range (1, 205, 1):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

                    elif varinput == 2 or varinput == 4: #if land or terrain
                        for fh in range (3, 205, 3):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
                    else:
                        print ("varinput error")
                else:
                    print ("memdict error")

elif runinput == 3: #if medium_range_no_da
    if varinput ==1:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 13, 6):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (3,240,3):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")    

elif runinput == 4: #if long_range
    for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
        date = dt.strftime('%Y%m%d') 
        for fc in range (0, 19, 6):
            fcst_cycles = (f"{fc:02d}")

            if varinput == 1 or varinput ==3: #if channel or reservoir
                for fh in range (6, 721, 6):
                    fcst_hours = (f"{fh:03d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

            elif varinput == 2: #if land (no terrain)
                for fh in range (24, 721, 24):
                    fcst_hours = (f"{fh:03d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            else:
                print ("varinput error")
            
elif runinput == 5: #if analysis_assim (simplest form)
    if varinput == 5: #if forcing
       for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 20, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif varinput == 5 and geoinput == 2: #if forcing and hawaii
       for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 19, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 24, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            
elif runinput == 6: #if analysis_assim_extend
    for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
        date = dt.strftime('%Y%m%d') 
        fcst_cycles = "16"

        for fh in range (0,28,1):
           fcst_hours = (f"{fh:02d}")
           print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            
elif runinput == 7: #if analysis_assim_extend_no_da
    if varinput == 1:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 
            fcst_cycles = "16"
    
            for fh in range (0,28,1):
                fcst_hours = (f"{fh:02d}")
                print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")
            
elif runinput == 8: #if analysis_assim_long
    for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
        date = dt.strftime('%Y%m%d') 

        for fc in range (0, 24, 6):
            fcst_cycles = (f"{fc:02d}")
    
            for fh in range (0,12,1):
                fcst_hours = (f"{fh:02d}")
                print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            
elif runinput == 9: #if analysis_assim_long_no_da
    if varinput == 1:

        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 24, 6):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,12,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else: 
        print ("only valid variable for a _no_da type run is channel_rt")
            
elif runinput == 10: #if analysis_assim_no_da
    if varinput == 1:

        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 21, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")

elif ruinput == 11 and geoinput ==3 : #if short_range_puertorico_no_da
    if varinput == 1:

        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (6, 19, 12):
                fcst_cycles = (f"{fc:02d}") 
                for fh in range (1,49,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")
else:
    print ("run error")
# Out:
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220822/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220823/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t00z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t01z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t02z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t03z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t04z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t05z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t06z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t07z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t08z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t09z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t10z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t11z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t12z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t13z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t14z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t15z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t16z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t17z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t18z.analysis_assim.forcing.tm02.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm00.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm01.puertorico.nc
# nwm.20220824/forcing_analysis_assim_puertorico/nwm.t19z.analysis_assim.forcing.tm02.puertorico.nc
