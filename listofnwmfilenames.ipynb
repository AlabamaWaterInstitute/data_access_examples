# %% [markdown]
# ## List of NWM File Names
# ### This code will output a list of NWM file names corresponding to the NWM output files according to the following givens:
# - Date Range
# - Geography (conus, hawaii, or puerto rico)
# - Run type (short_range, medium_range, analysis_assim, etc.)
# - Variable type (channel_rt, land, reservoir, terrain_rt, or forcing)

# %% [markdown]
# Cell 1 defines dictionaries that hold the different options for geography, run type, variable type. An additional dictionary "memdict" holds options which correspond to different types of medium_range and long_range run types.

# %%
rundict = {
    1: "short_range",
    2: "medium_range",
    3: "medium_range_no_da",
    4: "long_range",
    5: "analysis_assim",
    6: "analysis_assim_extend",
    7: "analysis_assim_extend_no_da",
    8: "analysis_assim_long",
    9: "analysis_assim_long_no_da",
    10: "analysis_assim_no_da",
    11: "short_range_no_da"
}
memdict = {
    1: "mem_1",
    2: "mem_2",
    3: "mem_3",
    4: "mem_4",
    5: "mem_5",
    6: "mem_6",
    7: "mem_7"
}
vardict = {
    1: "channel_rt",
    2: "land",
    3: "reservoir",
    4: "terrain_rt",
    5: "forcing"
}
geodict = {
    1: "conus",
    2: "hawaii",
    3: "puertorico"
}
fcst_cycle = "00"
fcst_hour = "001"
runsuffix = ""

# %% [markdown]
# Cell 2 contains some notes about the limitations of the program.

# %%
#although forcing is a type of run, it is handled as a variable type

#for _no_da run types, the only variable input can be channel_rt

#short_range_hawaii, short_range_hawaii_no_da, analysis_assim_hawaii, and analysis_assim_hawaii_no_da cannot be accomodated because they output every 15 minutes

#runsuffix is not being used, but i'm not going to delete it from everything just in case this whole thing needs to be restructured

# %% [markdown]
# Cell 3 defines the function "makename" which forms the file name outputs.

# %%
def makename (date, run, var, fcst_cycle, fcst_hour, geography, run_type, fhprefix = "", runsuffix = "", varsuffix = "", run_typesuffix = ""):
    return f"nwm.{date}/{run_type}{run_typesuffix}/nwm.t{fcst_cycle}z.{run}{runsuffix}.{var}{varsuffix}.{fhprefix}{fcst_hour}.{geography}.nc"

# %% [markdown]
# Cell 4 introduces the date range function that will be utilized, given a start date and an end date.

# %%
from dateutil import rrule
from datetime import datetime

start_date = "20220822"
end_date = "20220824"

for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
    date = dt.strftime('%Y%m%d')

# %% [markdown]
# Cells 5 - 7 define selection functions that reach into the previously created dictionaries and return the necessary variable given a dictionary key input.

# %%
varinput = 2

def selectvar(vardict, varinput):
    return vardict[varinput]

try:
    var = selectvar(vardict, varinput)
except:
    var = "variable_error"

# %%
geoinput = 1

def selectgeo(geodict, geoinput):
    return geodict[geoinput]

try:
    geography = selectgeo(geodict, geoinput)
except:
    georaphy = "geography_error"

# %%
runinput = 2

def selectrun(rundict, runinput):
    return rundict[runinput]

try:
    run = selectrun(rundict, runinput)
except:
    run = "run_error"

# %% [markdown]
# Cell 8 deals with inconsistencies in the run type name between the folder names and the file names for specific run types.

# %%
#setting run_type 
if varinput == 5: #if forcing
    if runinput == 5 and geoinput == 2: #if analysis_assim and hawaii
        run_type = "forcing_analysis_assim_hawaii"
    elif runinput == 5 and geoinput == 3: #if analysis_assim and puerto rico
        run_type = "forcing_analysis_assim_puertorico"
    elif runinput == 1 and geoinput == 2: #if short range and hawaii
        run_type = "forcing_short_range_hawaii"
    elif runinput == 1 and geoinput == 3: #if short range and puerto rico
        run_type = "forcing_short_range_puertorico" 
    elif runinput == 5: #if analysis assim
        run_type = "forcing_analysis_assim"
    elif runinput == 6: #if analysis_assim_extend
        run_type = "forcing_analysis_assim_extend"
    elif runinput == 2: #if medium_range
        run_type = "forcing_medium_range"
    elif runinput == 1: #if short range
        run_type = "forcing_short_range"

elif runinput == 5 and geoinput == 3: #if analysis_assim and puertorico
    run_type = "analysis_assim_puertorico"

elif runinput == 10 and geoinput == 3: #if analysis_assim_no_da and puertorico
    run_type = "analysis_assim_puertorico_no_da"

elif runinput == 1 and geoinput == 3: #if short_range and puerto rico
    run_type = "short_range_puertorico"

elif runinput == 11 and geoinput ==3: #if short_range_no_da and puerto rico
    run_type = "short_range_puertorico_no_da"
    
else:
    run_type = run

# %% [markdown]
# Cell 9 creates the _mem# and _# additions to the names of medium_range and long_range run types.

# %%
#setting varsuffix and run_typesuffix (for the file path folder name)
memdict = 3

if memdict == 1:
    varsuffix = "_1"
    run_typesuffix = "_mem1"
elif memdict == 2:
    varsuffix = "_2"
    run_typesuffix = "_mem2"
elif memdict == 3:
    varsuffix = "_3"
    run_typesuffix = "_mem3"
elif memdict == 4:
    varsuffix = "_4"
    run_typesuffix = "_mem4"
elif memdict == 5:
    varsuffix = "_5"
    run_typesuffix = "_mem5"
elif memdict == 6:
    varsuffix = "_6"
    run_typesuffix = "_mem6"
elif memdict == 7:
    varsuffix = "_7"
    run_typesuffix = "_mem7"
else:
    varsuffix = ""
    run_typesuffix = ""

# %% [markdown]
# Cell 10 deals with inconsistencies of the forecast hour prefix between analysis_assim and all other run types.

# %%
#setting fhprefix
if runinput == 4 or runinput == 5 or runinput == 6 or runinput == 7 or runinput == 8 or runinput == 9 or runinput == 10: #if analysis_assim (any type)
    fhprefix = "tm"
else:
    fhprefix = "f"

# %% [markdown]
# Cell 11 does the actual work of creating the list of file names for each scenario of inputs.

# %%
#for given date,  run, var, fcst_cycle, and geography, print file names for the valid time (the range of fcst_hours) and dates

if runinput == 1: #if short_range
    if varinput == 5: #if forcing
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') #create date range

            for fc in range (0, 29, 1):
                fcst_cycles = (f"{fc:02d}") #create forecast cycle range

                for fh in range (1,19,1):
                    fcst_hours = (f"{fh:03d}") #create forecast hours range
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif varinput == 5 and geoinput == 2: #if forcing and hawaii
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 13, 12):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (1,49,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif varinput == 5 and geoinput == 3: #if forcing and puerto rico
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            fcst_cycles = "06"

            for fh in range (1,48,1):
                fcst_hours = (f"{fh:03d}") 
                print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif geoinput == 3: #if puerto rico
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (6, 19, 12):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (1,48,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d')
            for fc in range (0, 24, 1):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (1,19,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

elif runinput == 2: #if medium_range
    if varinput == 5: #if forcing
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 13, 6):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (0,240,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 
            for fc in range (0, 19, 6):
                fcst_cycles = (f"{fc:02d}")

                if memdict == 1: #if medium_range_mem1
                    if varinput == 1 or varinput == 3: #if channel or reservoir
                        for fh in range (1, 241, 1):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

                    elif varinput == 2 or varinput ==4: #if land or terrain
                        for fh in range (3, 241, 3):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
                    else:
                        print ("varinput error")

                elif memdict == 2 or memdict == 3 or memdict == 4 or memdict == 5 or memdict == 6 or memdict == 7:#if medium_range_mem_2 through _mem7
                    if varinput == 1 or varinput ==3: #if channel or reservoir
                        for fh in range (1, 205, 1):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

                    elif varinput == 2 or varinput == 4: #if land or terrain
                        for fh in range (3, 205, 3):
                            fcst_hours = (f"{fh:03d}") 
                            print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
                    else:
                        print ("varinput error")
                else:
                    print ("memdict error")

elif runinput == 3: #if medium_range_no_da
    if varinput ==1:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 13, 6):
                fcst_cycles = (f"{fc:02d}") 

                for fh in range (3,240,3):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")    

elif runinput == 4: #if long_range
    for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
        date = dt.strftime('%Y%m%d') 
        for fc in range (0, 19, 6):
            fcst_cycles = (f"{fc:02d}")

            if varinput == 1 or varinput ==3: #if channel or reservoir
                for fh in range (6, 721, 6):
                    fcst_hours = (f"{fh:03d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

            elif varinput == 2: #if land (no terrain)
                for fh in range (24, 721, 24):
                    fcst_hours = (f"{fh:03d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            else:
                print ("varinput error")
            
elif runinput == 5: #if analysis_assim (simplest form)
    if varinput == 5: #if forcing
       for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 20, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))

    elif varinput == 5 and geoinput == 2: #if forcing and hawaii
       for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 19, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 24, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            
elif runinput == 6: #if analysis_assim_extend
    for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
        date = dt.strftime('%Y%m%d') 
        fcst_cycles = "16"

        for fh in range (0,28,1):
           fcst_hours = (f"{fh:02d}")
           print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            
elif runinput == 7: #if analysis_assim_extend_no_da
    if varinput == 1:
        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 
            fcst_cycles = "16"
    
            for fh in range (0,28,1):
                fcst_hours = (f"{fh:02d}")
                print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")
            
elif runinput == 8: #if analysis_assim_long
    for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
        date = dt.strftime('%Y%m%d') 

        for fc in range (0, 24, 6):
            fcst_cycles = (f"{fc:02d}")
    
            for fh in range (0,12,1):
                fcst_hours = (f"{fh:02d}")
                print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
            
elif runinput == 9: #if analysis_assim_long_no_da
    if varinput == 1:

        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 24, 6):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,12,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else: 
        print ("only valid variable for a _no_da type run is channel_rt")
            
elif runinput == 10: #if analysis_assim_no_da
    if varinput == 1:

        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (0, 21, 1):
                fcst_cycles = (f"{fc:02d}")

                for fh in range (0,3,1):
                    fcst_hours = (f"{fh:02d}")
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")

elif runinput == 11 and geoinput ==3 : #if short_range_puertorico_no_da
    if varinput == 1:

        for dt in rrule.rrule(rrule.DAILY, dtstart=datetime.strptime(start_date, '%Y%m%d'), until=datetime.strptime(end_date, '%Y%m%d')):
            date = dt.strftime('%Y%m%d') 

            for fc in range (6, 19, 12):
                fcst_cycles = (f"{fc:02d}") 
                for fh in range (1,49,1):
                    fcst_hours = (f"{fh:03d}") 
                    print (makename(date, run, var, fcst_cycles, fcst_hours, geography, run_type, fhprefix, runsuffix, varsuffix, run_typesuffix))
    else:
        print ("only valid variable for a _no_da type run is channel_rt")
else:
    print ("run error")
# Out:
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f003.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f006.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f009.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f012.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f015.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f018.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f021.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f024.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f027.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f030.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f033.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f036.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f039.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f042.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f045.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f048.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f051.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f054.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f057.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f060.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f063.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f066.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f069.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f072.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f075.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f078.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f081.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f084.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f087.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f090.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f093.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f096.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f099.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f102.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f105.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f108.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f111.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f114.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f117.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f120.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f123.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f126.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f129.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f132.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f135.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f138.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f141.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f144.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f147.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f150.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f153.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f156.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f159.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f162.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f165.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f168.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f171.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f174.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f177.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f180.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f183.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f186.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f189.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f192.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f195.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f198.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f201.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t00z.medium_range.land_3.f204.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f003.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f006.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f009.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f012.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f015.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f018.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f021.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f024.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f027.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f030.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f033.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f036.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f039.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f042.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f045.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f048.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f051.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f054.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f057.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f060.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f063.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f066.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f069.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f072.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f075.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f078.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f081.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f084.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f087.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f090.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f093.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f096.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f099.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f102.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f105.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f108.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f111.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f114.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f117.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f120.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f123.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f126.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f129.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f132.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f135.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f138.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f141.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f144.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f147.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f150.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f153.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f156.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f159.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f162.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f165.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f168.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f171.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f174.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f177.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f180.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f183.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f186.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f189.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f192.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f195.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f198.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f201.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t06z.medium_range.land_3.f204.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f003.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f006.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f009.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f012.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f015.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f018.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f021.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f024.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f027.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f030.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f033.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f036.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f039.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f042.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f045.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f048.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f051.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f054.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f057.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f060.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f063.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f066.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f069.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f072.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f075.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f078.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f081.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f084.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f087.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f090.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f093.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f096.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f099.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f102.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f105.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f108.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f111.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f114.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f117.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f120.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f123.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f126.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f129.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f132.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f135.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f138.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f141.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f144.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f147.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f150.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f153.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f156.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f159.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f162.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f165.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f168.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f171.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f174.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f177.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f180.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f183.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f186.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f189.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f192.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f195.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f198.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f201.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t12z.medium_range.land_3.f204.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f003.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f006.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f009.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f012.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f015.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f018.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f021.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f024.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f027.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f030.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f033.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f036.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f039.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f042.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f045.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f048.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f051.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f054.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f057.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f060.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f063.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f066.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f069.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f072.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f075.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f078.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f081.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f084.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f087.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f090.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f093.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f096.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f099.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f102.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f105.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f108.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f111.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f114.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f117.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f120.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f123.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f126.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f129.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f132.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f135.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f138.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f141.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f144.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f147.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f150.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f153.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f156.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f159.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f162.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f165.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f168.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f171.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f174.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f177.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f180.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f183.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f186.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f189.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f192.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f195.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f198.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f201.conus.nc
# nwm.20220822/medium_range_mem3/nwm.t18z.medium_range.land_3.f204.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f003.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f006.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f009.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f012.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f015.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f018.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f021.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f024.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f027.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f030.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f033.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f036.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f039.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f042.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f045.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f048.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f051.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f054.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f057.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f060.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f063.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f066.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f069.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f072.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f075.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f078.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f081.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f084.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f087.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f090.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f093.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f096.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f099.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f102.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f105.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f108.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f111.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f114.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f117.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f120.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f123.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f126.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f129.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f132.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f135.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f138.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f141.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f144.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f147.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f150.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f153.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f156.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f159.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f162.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f165.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f168.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f171.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f174.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f177.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f180.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f183.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f186.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f189.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f192.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f195.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f198.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f201.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t00z.medium_range.land_3.f204.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f003.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f006.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f009.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f012.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f015.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f018.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f021.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f024.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f027.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f030.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f033.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f036.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f039.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f042.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f045.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f048.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f051.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f054.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f057.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f060.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f063.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f066.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f069.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f072.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f075.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f078.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f081.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f084.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f087.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f090.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f093.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f096.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f099.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f102.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f105.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f108.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f111.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f114.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f117.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f120.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f123.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f126.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f129.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f132.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f135.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f138.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f141.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f144.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f147.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f150.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f153.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f156.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f159.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f162.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f165.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f168.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f171.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f174.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f177.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f180.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f183.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f186.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f189.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f192.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f195.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f198.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f201.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t06z.medium_range.land_3.f204.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f003.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f006.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f009.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f012.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f015.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f018.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f021.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f024.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f027.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f030.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f033.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f036.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f039.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f042.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f045.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f048.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f051.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f054.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f057.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f060.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f063.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f066.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f069.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f072.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f075.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f078.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f081.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f084.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f087.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f090.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f093.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f096.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f099.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f102.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f105.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f108.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f111.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f114.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f117.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f120.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f123.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f126.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f129.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f132.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f135.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f138.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f141.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f144.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f147.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f150.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f153.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f156.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f159.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f162.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f165.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f168.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f171.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f174.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f177.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f180.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f183.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f186.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f189.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f192.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f195.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f198.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f201.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t12z.medium_range.land_3.f204.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f003.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f006.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f009.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f012.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f015.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f018.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f021.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f024.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f027.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f030.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f033.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f036.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f039.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f042.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f045.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f048.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f051.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f054.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f057.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f060.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f063.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f066.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f069.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f072.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f075.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f078.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f081.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f084.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f087.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f090.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f093.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f096.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f099.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f102.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f105.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f108.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f111.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f114.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f117.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f120.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f123.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f126.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f129.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f132.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f135.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f138.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f141.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f144.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f147.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f150.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f153.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f156.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f159.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f162.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f165.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f168.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f171.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f174.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f177.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f180.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f183.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f186.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f189.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f192.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f195.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f198.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f201.conus.nc
# nwm.20220823/medium_range_mem3/nwm.t18z.medium_range.land_3.f204.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f003.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f006.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f009.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f012.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f015.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f018.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f021.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f024.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f027.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f030.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f033.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f036.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f039.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f042.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f045.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f048.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f051.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f054.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f057.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f060.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f063.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f066.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f069.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f072.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f075.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f078.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f081.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f084.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f087.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f090.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f093.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f096.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f099.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f102.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f105.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f108.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f111.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f114.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f117.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f120.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f123.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f126.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f129.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f132.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f135.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f138.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f141.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f144.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f147.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f150.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f153.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f156.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f159.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f162.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f165.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f168.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f171.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f174.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f177.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f180.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f183.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f186.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f189.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f192.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f195.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f198.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f201.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t00z.medium_range.land_3.f204.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f003.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f006.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f009.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f012.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f015.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f018.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f021.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f024.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f027.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f030.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f033.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f036.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f039.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f042.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f045.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f048.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f051.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f054.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f057.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f060.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f063.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f066.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f069.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f072.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f075.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f078.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f081.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f084.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f087.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f090.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f093.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f096.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f099.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f102.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f105.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f108.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f111.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f114.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f117.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f120.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f123.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f126.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f129.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f132.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f135.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f138.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f141.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f144.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f147.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f150.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f153.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f156.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f159.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f162.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f165.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f168.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f171.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f174.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f177.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f180.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f183.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f186.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f189.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f192.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f195.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f198.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f201.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t06z.medium_range.land_3.f204.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f003.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f006.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f009.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f012.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f015.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f018.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f021.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f024.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f027.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f030.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f033.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f036.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f039.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f042.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f045.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f048.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f051.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f054.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f057.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f060.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f063.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f066.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f069.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f072.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f075.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f078.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f081.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f084.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f087.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f090.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f093.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f096.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f099.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f102.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f105.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f108.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f111.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f114.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f117.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f120.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f123.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f126.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f129.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f132.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f135.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f138.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f141.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f144.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f147.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f150.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f153.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f156.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f159.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f162.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f165.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f168.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f171.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f174.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f177.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f180.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f183.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f186.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f189.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f192.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f195.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f198.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f201.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t12z.medium_range.land_3.f204.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f003.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f006.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f009.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f012.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f015.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f018.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f021.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f024.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f027.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f030.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f033.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f036.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f039.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f042.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f045.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f048.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f051.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f054.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f057.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f060.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f063.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f066.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f069.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f072.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f075.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f078.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f081.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f084.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f087.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f090.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f093.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f096.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f099.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f102.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f105.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f108.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f111.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f114.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f117.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f120.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f123.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f126.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f129.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f132.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f135.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f138.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f141.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f144.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f147.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f150.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f153.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f156.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f159.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f162.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f165.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f168.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f171.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f174.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f177.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f180.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f183.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f186.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f189.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f192.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f195.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f198.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f201.conus.nc
# nwm.20220824/medium_range_mem3/nwm.t18z.medium_range.land_3.f204.conus.nc

# %% [markdown]
# The next step will be to create an interactive dashboard
