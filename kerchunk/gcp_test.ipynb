# %%
import warnings
warnings.filterwarnings('ignore')

from gcp import NWMData

# %%
NWMdata = NWMData()

# %%
start_date='20220915'
end_date='20220916'
configuration = 'short_range'

# %%
files = NWMdata.get_files(start_date, end_date, configuration)

# %%
# %%time
ds = NWMdata.get_dataset(start_date, end_date, configuration)
# Out:
# CPU times: user 1min 8s, sys: 5.73 s, total: 1min 14s
# Wall time: 3min 10s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 65, reference_time: 48, feature_id: 2776738)
# Coordinates:
#   * feature_id      (feature_id) float64 101.0 179.0 181.0 ... 1.18e+09 1.18e+09
#   * reference_time  (reference_time) datetime64[ns] 2022-09-15 ... 2022-09-16...
#   * time            (time) datetime64[ns] 2022-09-15T01:00:00 ... 2022-09-17T...
# Data variables:
#     crs             (time, reference_time) object ...
#     nudge           (time, reference_time, feature_id) float64 ...
#     qBtmVertRunoff  (time, reference_time, feature_id) float64 ...
#     qBucket         (time, reference_time, feature_id) float64 ...
#     qSfcLatRunoff   (time, reference_time, feature_id) float64 ...
#     streamflow      (time, reference_time, feature_id) float64 ...
#     velocity        (time, reference_time, feature_id) float64 ...
# Attributes: (12/19)
#     Conventions:                CF-1.6
#     NWM_version_number:         v2.2
# ...
